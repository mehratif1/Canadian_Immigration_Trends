# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/dariareichkina/Projects/Project3/Resources/Income/1110019001_databaseLoadingData-2.csv")

# %%
df.head(20)
# Out:
#     REF_DATE                 GEO       DGUID        Income concept  \
# 0       2006  Atlantic provinces  2016A00011  Median market income
# 1       2007  Atlantic provinces  2016A00011  Median market income
# 2       2008  Atlantic provinces  2016A00011  Median market income
# 3       2009  Atlantic provinces  2016A00011  Median market income
# 4       2010  Atlantic provinces  2016A00011  Median market income
# 5       2011  Atlantic provinces  2016A00011  Median market income
# 6       2012  Atlantic provinces  2016A00011  Median market income
# 7       2013  Atlantic provinces  2016A00011  Median market income
# 8       2014  Atlantic provinces  2016A00011  Median market income
# 9       2015  Atlantic provinces  2016A00011  Median market income
# 10      2016  Atlantic provinces  2016A00011  Median market income
# 11      2017  Atlantic provinces  2016A00011  Median market income
# 12      2018  Atlantic provinces  2016A00011  Median market income
# ...

# %%
df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Income concept', 'Economic family type',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
income_AtlProv = df.drop(df.index[16:])

# %%
income_AtlProv.head(17)
# Out:
#     REF_DATE                 GEO       DGUID        Income concept  \
# 0       2006  Atlantic provinces  2016A00011  Median market income
# 1       2007  Atlantic provinces  2016A00011  Median market income
# 2       2008  Atlantic provinces  2016A00011  Median market income
# 3       2009  Atlantic provinces  2016A00011  Median market income
# 4       2010  Atlantic provinces  2016A00011  Median market income
# 5       2011  Atlantic provinces  2016A00011  Median market income
# 6       2012  Atlantic provinces  2016A00011  Median market income
# 7       2013  Atlantic provinces  2016A00011  Median market income
# 8       2014  Atlantic provinces  2016A00011  Median market income
# 9       2015  Atlantic provinces  2016A00011  Median market income
# 10      2016  Atlantic provinces  2016A00011  Median market income
# 11      2017  Atlantic provinces  2016A00011  Median market income
# 12      2018  Atlantic provinces  2016A00011  Median market income
# ...

# %%
df = pd.read_csv("/Users/dariareichkina/Projects/Project3/Resources/Income/1110019001_databaseLoadingData-3.csv")

# %%
df.head(20)
# Out:
#     REF_DATE                        GEO        DGUID        Income concept  \
# 0       2006  Newfoundland and Labrador  2016A000210  Median market income
# 1       2007  Newfoundland and Labrador  2016A000210  Median market income
# 2       2008  Newfoundland and Labrador  2016A000210  Median market income
# 3       2009  Newfoundland and Labrador  2016A000210  Median market income
# 4       2010  Newfoundland and Labrador  2016A000210  Median market income
# 5       2011  Newfoundland and Labrador  2016A000210  Median market income
# 6       2012  Newfoundland and Labrador  2016A000210  Median market income
# 7       2013  Newfoundland and Labrador  2016A000210  Median market income
# 8       2014  Newfoundland and Labrador  2016A000210  Median market income
# 9       2015  Newfoundland and Labrador  2016A000210  Median market income
# 10      2016  Newfoundland and Labrador  2016A000210  Median market income
# ...

# %%
income_NFL = df.drop(df.index[16:])

# %%
income_NFL.head(17)
# Out:
#     REF_DATE                        GEO        DGUID        Income concept  \
# 0       2006  Newfoundland and Labrador  2016A000210  Median market income
# 1       2007  Newfoundland and Labrador  2016A000210  Median market income
# 2       2008  Newfoundland and Labrador  2016A000210  Median market income
# 3       2009  Newfoundland and Labrador  2016A000210  Median market income
# 4       2010  Newfoundland and Labrador  2016A000210  Median market income
# 5       2011  Newfoundland and Labrador  2016A000210  Median market income
# 6       2012  Newfoundland and Labrador  2016A000210  Median market income
# 7       2013  Newfoundland and Labrador  2016A000210  Median market income
# 8       2014  Newfoundland and Labrador  2016A000210  Median market income
# 9       2015  Newfoundland and Labrador  2016A000210  Median market income
# 10      2016  Newfoundland and Labrador  2016A000210  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-4.csv")

# %%
df.head(20)
# Out:
#     REF_DATE                   GEO        DGUID        Income concept  \
# 0       2006  Prince Edward Island  2016A000211  Median market income
# 1       2007  Prince Edward Island  2016A000211  Median market income
# 2       2008  Prince Edward Island  2016A000211  Median market income
# 3       2009  Prince Edward Island  2016A000211  Median market income
# 4       2010  Prince Edward Island  2016A000211  Median market income
# 5       2011  Prince Edward Island  2016A000211  Median market income
# 6       2012  Prince Edward Island  2016A000211  Median market income
# 7       2013  Prince Edward Island  2016A000211  Median market income
# 8       2014  Prince Edward Island  2016A000211  Median market income
# 9       2015  Prince Edward Island  2016A000211  Median market income
# 10      2016  Prince Edward Island  2016A000211  Median market income
# 11      2017  Prince Edward Island  2016A000211  Median market income
# ...

# %%
income_PEI = df.drop(df.index[16:])

# %%
income_PEI.head(17)
# Out:
#     REF_DATE                   GEO        DGUID        Income concept  \
# 0       2006  Prince Edward Island  2016A000211  Median market income
# 1       2007  Prince Edward Island  2016A000211  Median market income
# 2       2008  Prince Edward Island  2016A000211  Median market income
# 3       2009  Prince Edward Island  2016A000211  Median market income
# 4       2010  Prince Edward Island  2016A000211  Median market income
# 5       2011  Prince Edward Island  2016A000211  Median market income
# 6       2012  Prince Edward Island  2016A000211  Median market income
# 7       2013  Prince Edward Island  2016A000211  Median market income
# 8       2014  Prince Edward Island  2016A000211  Median market income
# 9       2015  Prince Edward Island  2016A000211  Median market income
# 10      2016  Prince Edward Island  2016A000211  Median market income
# 11      2017  Prince Edward Island  2016A000211  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-5.csv")
df.head(20)
# Out:
#     REF_DATE          GEO        DGUID        Income concept  \
# 0       2006  Nova Scotia  2016A000212  Median market income
# 1       2007  Nova Scotia  2016A000212  Median market income
# 2       2008  Nova Scotia  2016A000212  Median market income
# 3       2009  Nova Scotia  2016A000212  Median market income
# 4       2010  Nova Scotia  2016A000212  Median market income
# 5       2011  Nova Scotia  2016A000212  Median market income
# 6       2012  Nova Scotia  2016A000212  Median market income
# 7       2013  Nova Scotia  2016A000212  Median market income
# 8       2014  Nova Scotia  2016A000212  Median market income
# 9       2015  Nova Scotia  2016A000212  Median market income
# 10      2016  Nova Scotia  2016A000212  Median market income
# 11      2017  Nova Scotia  2016A000212  Median market income
# 12      2018  Nova Scotia  2016A000212  Median market income
# 13      2019  Nova Scotia  2016A000212  Median market income
# ...

# %%
income_NS = df.drop(df.index[16:])
income_NS.head(17)
# Out:
#     REF_DATE          GEO        DGUID        Income concept  \
# 0       2006  Nova Scotia  2016A000212  Median market income
# 1       2007  Nova Scotia  2016A000212  Median market income
# 2       2008  Nova Scotia  2016A000212  Median market income
# 3       2009  Nova Scotia  2016A000212  Median market income
# 4       2010  Nova Scotia  2016A000212  Median market income
# 5       2011  Nova Scotia  2016A000212  Median market income
# 6       2012  Nova Scotia  2016A000212  Median market income
# 7       2013  Nova Scotia  2016A000212  Median market income
# 8       2014  Nova Scotia  2016A000212  Median market income
# 9       2015  Nova Scotia  2016A000212  Median market income
# 10      2016  Nova Scotia  2016A000212  Median market income
# 11      2017  Nova Scotia  2016A000212  Median market income
# 12      2018  Nova Scotia  2016A000212  Median market income
# 13      2019  Nova Scotia  2016A000212  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-6.csv")
df.head(20)
# Out:
#     REF_DATE            GEO        DGUID        Income concept  \
# 0       2006  New Brunswick  2016A000213  Median market income
# 1       2007  New Brunswick  2016A000213  Median market income
# 2       2008  New Brunswick  2016A000213  Median market income
# 3       2009  New Brunswick  2016A000213  Median market income
# 4       2010  New Brunswick  2016A000213  Median market income
# 5       2011  New Brunswick  2016A000213  Median market income
# 6       2012  New Brunswick  2016A000213  Median market income
# 7       2013  New Brunswick  2016A000213  Median market income
# 8       2014  New Brunswick  2016A000213  Median market income
# 9       2015  New Brunswick  2016A000213  Median market income
# 10      2016  New Brunswick  2016A000213  Median market income
# 11      2017  New Brunswick  2016A000213  Median market income
# 12      2018  New Brunswick  2016A000213  Median market income
# 13      2019  New Brunswick  2016A000213  Median market income
# ...

# %%
income_NB = df.drop(df.index[16:])
income_NB.head(17)
# Out:
#     REF_DATE            GEO        DGUID        Income concept  \
# 0       2006  New Brunswick  2016A000213  Median market income
# 1       2007  New Brunswick  2016A000213  Median market income
# 2       2008  New Brunswick  2016A000213  Median market income
# 3       2009  New Brunswick  2016A000213  Median market income
# 4       2010  New Brunswick  2016A000213  Median market income
# 5       2011  New Brunswick  2016A000213  Median market income
# 6       2012  New Brunswick  2016A000213  Median market income
# 7       2013  New Brunswick  2016A000213  Median market income
# 8       2014  New Brunswick  2016A000213  Median market income
# 9       2015  New Brunswick  2016A000213  Median market income
# 10      2016  New Brunswick  2016A000213  Median market income
# 11      2017  New Brunswick  2016A000213  Median market income
# 12      2018  New Brunswick  2016A000213  Median market income
# 13      2019  New Brunswick  2016A000213  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-7.csv")
df.head(20)
# Out:
#     REF_DATE     GEO        DGUID        Income concept  \
# 0       2006  Quebec  2016A000224  Median market income
# 1       2007  Quebec  2016A000224  Median market income
# 2       2008  Quebec  2016A000224  Median market income
# 3       2009  Quebec  2016A000224  Median market income
# 4       2010  Quebec  2016A000224  Median market income
# 5       2011  Quebec  2016A000224  Median market income
# 6       2012  Quebec  2016A000224  Median market income
# 7       2013  Quebec  2016A000224  Median market income
# 8       2014  Quebec  2016A000224  Median market income
# 9       2015  Quebec  2016A000224  Median market income
# 10      2016  Quebec  2016A000224  Median market income
# 11      2017  Quebec  2016A000224  Median market income
# 12      2018  Quebec  2016A000224  Median market income
# 13      2019  Quebec  2016A000224  Median market income
# 14      2020  Quebec  2016A000224  Median market income
# 15      2021  Quebec  2016A000224  Median market income
# ...

# %%
income_QB = df.drop(df.index[16:])
income_QB.head(17)
# Out:
#     REF_DATE     GEO        DGUID        Income concept  \
# 0       2006  Quebec  2016A000224  Median market income
# 1       2007  Quebec  2016A000224  Median market income
# 2       2008  Quebec  2016A000224  Median market income
# 3       2009  Quebec  2016A000224  Median market income
# 4       2010  Quebec  2016A000224  Median market income
# 5       2011  Quebec  2016A000224  Median market income
# 6       2012  Quebec  2016A000224  Median market income
# 7       2013  Quebec  2016A000224  Median market income
# 8       2014  Quebec  2016A000224  Median market income
# 9       2015  Quebec  2016A000224  Median market income
# 10      2016  Quebec  2016A000224  Median market income
# 11      2017  Quebec  2016A000224  Median market income
# 12      2018  Quebec  2016A000224  Median market income
# 13      2019  Quebec  2016A000224  Median market income
# 14      2020  Quebec  2016A000224  Median market income
# 15      2021  Quebec  2016A000224  Median market income
#
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-8.csv")
df.head(20)
# Out:
#     REF_DATE      GEO        DGUID        Income concept  \
# 0       2006  Ontario  2016A000235  Median market income
# 1       2007  Ontario  2016A000235  Median market income
# 2       2008  Ontario  2016A000235  Median market income
# 3       2009  Ontario  2016A000235  Median market income
# 4       2010  Ontario  2016A000235  Median market income
# 5       2011  Ontario  2016A000235  Median market income
# 6       2012  Ontario  2016A000235  Median market income
# 7       2013  Ontario  2016A000235  Median market income
# 8       2014  Ontario  2016A000235  Median market income
# 9       2015  Ontario  2016A000235  Median market income
# 10      2016  Ontario  2016A000235  Median market income
# 11      2017  Ontario  2016A000235  Median market income
# 12      2018  Ontario  2016A000235  Median market income
# 13      2019  Ontario  2016A000235  Median market income
# 14      2020  Ontario  2016A000235  Median market income
# ...

# %%
income_ON = df.drop(df.index[16:])
income_ON.head(17)
# Out:
#     REF_DATE      GEO        DGUID        Income concept  \
# 0       2006  Ontario  2016A000235  Median market income
# 1       2007  Ontario  2016A000235  Median market income
# 2       2008  Ontario  2016A000235  Median market income
# 3       2009  Ontario  2016A000235  Median market income
# 4       2010  Ontario  2016A000235  Median market income
# 5       2011  Ontario  2016A000235  Median market income
# 6       2012  Ontario  2016A000235  Median market income
# 7       2013  Ontario  2016A000235  Median market income
# 8       2014  Ontario  2016A000235  Median market income
# 9       2015  Ontario  2016A000235  Median market income
# 10      2016  Ontario  2016A000235  Median market income
# 11      2017  Ontario  2016A000235  Median market income
# 12      2018  Ontario  2016A000235  Median market income
# 13      2019  Ontario  2016A000235  Median market income
# 14      2020  Ontario  2016A000235  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-9.csv")
df.head(20)
# Out:
#     REF_DATE                GEO       DGUID        Income concept  \
# 0       2006  Prairie provinces  2016A00014  Median market income
# 1       2007  Prairie provinces  2016A00014  Median market income
# 2       2008  Prairie provinces  2016A00014  Median market income
# 3       2009  Prairie provinces  2016A00014  Median market income
# 4       2010  Prairie provinces  2016A00014  Median market income
# 5       2011  Prairie provinces  2016A00014  Median market income
# 6       2012  Prairie provinces  2016A00014  Median market income
# 7       2013  Prairie provinces  2016A00014  Median market income
# 8       2014  Prairie provinces  2016A00014  Median market income
# 9       2015  Prairie provinces  2016A00014  Median market income
# 10      2016  Prairie provinces  2016A00014  Median market income
# 11      2017  Prairie provinces  2016A00014  Median market income
# 12      2018  Prairie provinces  2016A00014  Median market income
# ...

# %%
income_Prairie = df.drop(df.index[16:])
income_Prairie.head(17)
# Out:
#     REF_DATE                GEO       DGUID        Income concept  \
# 0       2006  Prairie provinces  2016A00014  Median market income
# 1       2007  Prairie provinces  2016A00014  Median market income
# 2       2008  Prairie provinces  2016A00014  Median market income
# 3       2009  Prairie provinces  2016A00014  Median market income
# 4       2010  Prairie provinces  2016A00014  Median market income
# 5       2011  Prairie provinces  2016A00014  Median market income
# 6       2012  Prairie provinces  2016A00014  Median market income
# 7       2013  Prairie provinces  2016A00014  Median market income
# 8       2014  Prairie provinces  2016A00014  Median market income
# 9       2015  Prairie provinces  2016A00014  Median market income
# 10      2016  Prairie provinces  2016A00014  Median market income
# 11      2017  Prairie provinces  2016A00014  Median market income
# 12      2018  Prairie provinces  2016A00014  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-10.csv")
df.head(20)
# Out:
#     REF_DATE       GEO        DGUID        Income concept  \
# 0       2006  Manitoba  2016A000246  Median market income
# 1       2007  Manitoba  2016A000246  Median market income
# 2       2008  Manitoba  2016A000246  Median market income
# 3       2009  Manitoba  2016A000246  Median market income
# 4       2010  Manitoba  2016A000246  Median market income
# 5       2011  Manitoba  2016A000246  Median market income
# 6       2012  Manitoba  2016A000246  Median market income
# 7       2013  Manitoba  2016A000246  Median market income
# 8       2014  Manitoba  2016A000246  Median market income
# 9       2015  Manitoba  2016A000246  Median market income
# 10      2016  Manitoba  2016A000246  Median market income
# 11      2017  Manitoba  2016A000246  Median market income
# 12      2018  Manitoba  2016A000246  Median market income
# 13      2019  Manitoba  2016A000246  Median market income
# 14      2020  Manitoba  2016A000246  Median market income
# ...

# %%
income_MN = df.drop(df.index[16:])
income_MN.head(17)
# Out:
#     REF_DATE       GEO        DGUID        Income concept  \
# 0       2006  Manitoba  2016A000246  Median market income
# 1       2007  Manitoba  2016A000246  Median market income
# 2       2008  Manitoba  2016A000246  Median market income
# 3       2009  Manitoba  2016A000246  Median market income
# 4       2010  Manitoba  2016A000246  Median market income
# 5       2011  Manitoba  2016A000246  Median market income
# 6       2012  Manitoba  2016A000246  Median market income
# 7       2013  Manitoba  2016A000246  Median market income
# 8       2014  Manitoba  2016A000246  Median market income
# 9       2015  Manitoba  2016A000246  Median market income
# 10      2016  Manitoba  2016A000246  Median market income
# 11      2017  Manitoba  2016A000246  Median market income
# 12      2018  Manitoba  2016A000246  Median market income
# 13      2019  Manitoba  2016A000246  Median market income
# 14      2020  Manitoba  2016A000246  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-12.csv")
df.head(20)
# Out:
#     REF_DATE           GEO        DGUID        Income concept  \
# 0       2006  Saskatchewan  2016A000247  Median market income
# 1       2007  Saskatchewan  2016A000247  Median market income
# 2       2008  Saskatchewan  2016A000247  Median market income
# 3       2009  Saskatchewan  2016A000247  Median market income
# 4       2010  Saskatchewan  2016A000247  Median market income
# 5       2011  Saskatchewan  2016A000247  Median market income
# 6       2012  Saskatchewan  2016A000247  Median market income
# 7       2013  Saskatchewan  2016A000247  Median market income
# 8       2014  Saskatchewan  2016A000247  Median market income
# 9       2015  Saskatchewan  2016A000247  Median market income
# 10      2016  Saskatchewan  2016A000247  Median market income
# 11      2017  Saskatchewan  2016A000247  Median market income
# 12      2018  Saskatchewan  2016A000247  Median market income
# 13      2019  Saskatchewan  2016A000247  Median market income
# ...

# %%
income_SAS = df.drop(df.index[16:])
income_SAS.head(17)
# Out:
#     REF_DATE           GEO        DGUID        Income concept  \
# 0       2006  Saskatchewan  2016A000247  Median market income
# 1       2007  Saskatchewan  2016A000247  Median market income
# 2       2008  Saskatchewan  2016A000247  Median market income
# 3       2009  Saskatchewan  2016A000247  Median market income
# 4       2010  Saskatchewan  2016A000247  Median market income
# 5       2011  Saskatchewan  2016A000247  Median market income
# 6       2012  Saskatchewan  2016A000247  Median market income
# 7       2013  Saskatchewan  2016A000247  Median market income
# 8       2014  Saskatchewan  2016A000247  Median market income
# 9       2015  Saskatchewan  2016A000247  Median market income
# 10      2016  Saskatchewan  2016A000247  Median market income
# 11      2017  Saskatchewan  2016A000247  Median market income
# 12      2018  Saskatchewan  2016A000247  Median market income
# 13      2019  Saskatchewan  2016A000247  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-14.csv")
df.head(20)
# Out:
#     REF_DATE      GEO        DGUID        Income concept  \
# 0       2006  Alberta  2016A000248  Median market income
# 1       2007  Alberta  2016A000248  Median market income
# 2       2008  Alberta  2016A000248  Median market income
# 3       2009  Alberta  2016A000248  Median market income
# 4       2010  Alberta  2016A000248  Median market income
# 5       2011  Alberta  2016A000248  Median market income
# 6       2012  Alberta  2016A000248  Median market income
# 7       2013  Alberta  2016A000248  Median market income
# 8       2014  Alberta  2016A000248  Median market income
# 9       2015  Alberta  2016A000248  Median market income
# 10      2016  Alberta  2016A000248  Median market income
# 11      2017  Alberta  2016A000248  Median market income
# 12      2018  Alberta  2016A000248  Median market income
# 13      2019  Alberta  2016A000248  Median market income
# 14      2020  Alberta  2016A000248  Median market income
# ...

# %%
income_ALB = df.drop(df.index[16:])
income_ALB.head(17)
# Out:
#     REF_DATE      GEO        DGUID        Income concept  \
# 0       2006  Alberta  2016A000248  Median market income
# 1       2007  Alberta  2016A000248  Median market income
# 2       2008  Alberta  2016A000248  Median market income
# 3       2009  Alberta  2016A000248  Median market income
# 4       2010  Alberta  2016A000248  Median market income
# 5       2011  Alberta  2016A000248  Median market income
# 6       2012  Alberta  2016A000248  Median market income
# 7       2013  Alberta  2016A000248  Median market income
# 8       2014  Alberta  2016A000248  Median market income
# 9       2015  Alberta  2016A000248  Median market income
# 10      2016  Alberta  2016A000248  Median market income
# 11      2017  Alberta  2016A000248  Median market income
# 12      2018  Alberta  2016A000248  Median market income
# 13      2019  Alberta  2016A000248  Median market income
# 14      2020  Alberta  2016A000248  Median market income
# ...

# %%
df = pd.read_csv("1110019001_databaseLoadingData-15.csv")
df.head(20)
# Out:
#     REF_DATE               GEO        DGUID        Income concept  \
# 0       2006  British Columbia  2016A000259  Median market income
# 1       2007  British Columbia  2016A000259  Median market income
# 2       2008  British Columbia  2016A000259  Median market income
# 3       2009  British Columbia  2016A000259  Median market income
# 4       2010  British Columbia  2016A000259  Median market income
# 5       2011  British Columbia  2016A000259  Median market income
# 6       2012  British Columbia  2016A000259  Median market income
# 7       2013  British Columbia  2016A000259  Median market income
# 8       2014  British Columbia  2016A000259  Median market income
# 9       2015  British Columbia  2016A000259  Median market income
# 10      2016  British Columbia  2016A000259  Median market income
# 11      2017  British Columbia  2016A000259  Median market income
# 12      2018  British Columbia  2016A000259  Median market income
# ...

# %%
income_BC = df.drop(df.index[16:])
income_BC.head(17)
# Out:
#     REF_DATE               GEO        DGUID        Income concept  \
# 0       2006  British Columbia  2016A000259  Median market income
# 1       2007  British Columbia  2016A000259  Median market income
# 2       2008  British Columbia  2016A000259  Median market income
# 3       2009  British Columbia  2016A000259  Median market income
# 4       2010  British Columbia  2016A000259  Median market income
# 5       2011  British Columbia  2016A000259  Median market income
# 6       2012  British Columbia  2016A000259  Median market income
# 7       2013  British Columbia  2016A000259  Median market income
# 8       2014  British Columbia  2016A000259  Median market income
# 9       2015  British Columbia  2016A000259  Median market income
# 10      2016  British Columbia  2016A000259  Median market income
# 11      2017  British Columbia  2016A000259  Median market income
# 12      2018  British Columbia  2016A000259  Median market income
# ...

# %%
income_result1 = pd.concat([income_NFL, income_PEI, income_NS, income_NB, income_QB, income_ON, income_MN, income_SAS, income_ALB, income_BC], axis = 0)

# %%
income_result1.head(45)
# Out:
#     REF_DATE                        GEO        DGUID        Income concept  \
# 0       2006  Newfoundland and Labrador  2016A000210  Median market income
# 1       2007  Newfoundland and Labrador  2016A000210  Median market income
# 2       2008  Newfoundland and Labrador  2016A000210  Median market income
# 3       2009  Newfoundland and Labrador  2016A000210  Median market income
# 4       2010  Newfoundland and Labrador  2016A000210  Median market income
# 5       2011  Newfoundland and Labrador  2016A000210  Median market income
# 6       2012  Newfoundland and Labrador  2016A000210  Median market income
# 7       2013  Newfoundland and Labrador  2016A000210  Median market income
# 8       2014  Newfoundland and Labrador  2016A000210  Median market income
# 9       2015  Newfoundland and Labrador  2016A000210  Median market income
# 10      2016  Newfoundland and Labrador  2016A000210  Median market income
# ...

# %%
columnsToDrop = ['DGUID', 'Income concept', 'Economic family type',
       'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS']

# %%
#income_result2 = pd.DataFrame(income_result1, )

# %%
income_result1 = income_result1.drop(columns = ["DGUID", "Income concept", "Economic family type", "UOM", "UOM_ID", "SCALAR_FACTOR"], inplace = True)

# %%
income_result1.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 income_result1.head(10)
#
# AttributeError: 'NoneType' object has no attribute 'head'

# %%
excel_file_path = 'income_res.xlsx'

# %%
income_result1.to_excel(excel_file_path, index=False)
